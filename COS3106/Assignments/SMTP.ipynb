# %% [markdown]
# https://www.wpoven.com/tools/free-smtp-server-for-testing

# %%
from smtplib import SMTP
from email.message import EmailMessage

# %%
msg = EmailMessage()
msg.set_content('Just want to say hi')

msg['Subject'] = 'Hello World'
msg['From'] = 'sender@example.com'
msg['To'] = 'recipient@example.com'

with SMTP('smtp.freesmtpservers.com') as smtp:
    smtp.set_debuglevel(1)
    smtp.send_message(msg)
# Out:
# send: 'ehlo [172.28.0.12]\r\n'
# reply: b'250-tools.wpoven.com\r\n'
# reply: b'250-SIZE 33554432\r\n'
# reply: b'250-8BITMIME\r\n'
# reply: b'250-SMTPUTF8\r\n'
# reply: b'250 HELP\r\n'
# reply: retcode (250); Msg: b'tools.wpoven.com\nSIZE 33554432\n8BITMIME\nSMTPUTF8\nHELP'
# send: 'mail FROM:<sender@example.com> size=193\r\n'
# reply: b'250 OK\r\n'
# reply: retcode (250); Msg: b'OK'
# send: 'rcpt TO:<recipient@example.com>\r\n'
# reply: b'250 OK\r\n'
# reply: retcode (250); Msg: b'OK'
# send: 'data\r\n'
# reply: b'354 End data with <CR><LF>.<CR><LF>\r\n'
# reply: retcode (354); Msg: b'End data with <CR><LF>.<CR><LF>'
# data: (354, b'End data with <CR><LF>.<CR><LF>')
# send: b'Content-Type: text/plain; charset="utf-8"\r\nContent-Transfer-Encoding: 7bit\r\nMIME-Version: 1.0\r\nSubject: Hello World\r\nFrom: sender@example.com\r\nTo: recipient@example.com\r\n\r\nJust want to say hi\r\n.\r\n'
# reply: b'250 OK\r\n'
# reply: retcode (250); Msg: b'OK'
# data: (250, b'OK')
# send: 'QUIT\r\n'
# reply: b'221 Bye\r\n'
# reply: retcode (221); Msg: b'Bye'
