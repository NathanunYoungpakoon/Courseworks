# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Retreive data from UCI dataset

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
columns = ["age", "work-class", "fnlwgt", "education", "education-num","marital-status", "occupation", "relationship",
           "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"]
data = pd.read_csv(url, names=columns, sep=',', na_values='?', skipinitialspace=True)

# %% [markdown]
# ### Take 20 random samples of the dataset

# %%
data.sample(20)
# Out:
#        age        work-class  fnlwgt     education  education-num  \
# 17114   40           Private  174515       HS-grad              9
# 5315    32           Private  183356       HS-grad              9
# 29559   44           Private  110908     Assoc-voc             11
# 12723   46  Self-emp-not-inc  103538   Prof-school             15
# 24863   61           Private   34632          12th              8
# 20234   60  Self-emp-not-inc  218085       HS-grad              9
# 2903    42           Private  200574  Some-college             10
# 6087    19         State-gov  112432  Some-college             10
# 25967   43           Private  167265     Bachelors             13
# 27556   59  Self-emp-not-inc   98418       HS-grad              9
# 3162    45           Private   72896       HS-grad              9
# 15205   26           Private   34112     Assoc-voc             11
# 3478    35           Private  340428     Bachelors             13
# 17778   39           Private  387068       HS-grad              9
# 17410   43           Private  247880       HS-grad              9
# 23669   23           Private  329925  Some-college             10
# 5413    50         Local-gov  117791       HS-grad              9
# 30673   20               NaN  122244       HS-grad              9
# 27142   34           Private   24266     Assoc-voc             11
# 30034   59           Private  126668     Assoc-voc             11
#
#               marital-status         occupation   relationship   race     sex  \
# 17114                Widowed  Machine-op-inspct      Unmarried  White  Female
# 5315           Never-married       Craft-repair      Own-child  White    Male
# 29559     Married-civ-spouse   Transport-moving           Wife  White  Female
# 12723     Married-civ-spouse     Prof-specialty        Husband  White    Male
# 24863  Married-spouse-absent     Prof-specialty  Not-in-family  White    Male
# 20234     Married-civ-spouse      Other-service           Wife  Black  Female
# 2903      Married-civ-spouse              Sales        Husband  White    Male
# 6087           Never-married       Adm-clerical      Own-child  White    Male
# 25967     Married-civ-spouse       Craft-repair        Husband  White    Male
# 27556     Married-civ-spouse    Farming-fishing        Husband  White    Male
# 3162           Never-married  Machine-op-inspct  Not-in-family  White    Male
# 15205          Never-married      Other-service  Not-in-family  White    Male
# 3478           Never-married              Sales      Unmarried  White  Female
# 17778     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 17410          Never-married       Craft-repair  Not-in-family  White    Male
# 23669          Never-married  Handlers-cleaners      Own-child  White    Male
# 5413                Divorced       Adm-clerical  Not-in-family  White  Female
# 30673          Never-married                NaN  Not-in-family  White  Female
# 27142     Married-civ-spouse       Craft-repair        Husband  White    Male
# 30034     Married-civ-spouse     Prof-specialty        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 17114             0             0              40  United-States  <=50K
# 5315              0             0              40  United-States  <=50K
# 29559             0             0              25  United-States  <=50K
# 12723             0             0              65  United-States   >50K
# 24863             0             0              40  United-States  <=50K
# 20234             0             0              50  United-States  <=50K
# 2903              0             0              40  United-States  <=50K
# 6087              0             0              10  United-States  <=50K
# 25967             0             0              84  United-States   >50K
# 27556             0             0              20  United-States  <=50K
# 3162              0             0              40  United-States  <=50K
# 15205             0             0              40  United-States  <=50K
# 3478              0             0              40  United-States   >50K
# 17778             0             0              40  United-States   >50K
# 17410             0             0              40  United-States  <=50K
# 23669             0             0              30  United-States  <=50K
# 5413              0             0              40  United-States  <=50K
# 30673             0             0              28  United-States  <=50K
# 27142          7688             0              40  United-States   >50K
# 30034          5178             0              50  United-States   >50K

# %% [markdown]
# ### Check how much are the missing data

# %%
print("Missing value count occupation: ", data['occupation'].isnull().sum())
print("Missing value count work-class: ", data['work-class'].isnull().sum())
print("Missing value count native-country: ", data['native-country'].isnull().sum())
# Out:
# Missing value count occupation:  1843
# Missing value count work-class:  1836
# Missing value count native-country:  583

# %%
data_nona = data.dropna().drop_duplicates()

plt.pie([
    data.shape[0],
    data.shape[0] - data_nona.shape[0]
],
autopct='%.0f%%', textprops={'size': '18'},
colors=plt.colormaps["Pastel1"]([0, 1]))
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
# Out:
# ([<matplotlib.patches.Wedge at 0x79826f301840>,
#   <matplotlib.patches.Wedge at 0x79826f301780>],
#  [Text(-1.0740830340664032, 0.23737235713264912, ''),
#   Text(1.0740830118419944, -0.2373724576955599, '')],
#  [Text(-0.5858634731271289, 0.12947583116326314, '93%'),
#   Text(0.5858634610047242, -0.12947588601575993, '7%')])

# %% [markdown]
# ### Use only rows that don't have missing values or duplicated values.

# %%
data = data_nona

# %% [markdown]
# ### Descriptive Statistics

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  30139.000000  3.013900e+04   30139.000000  30139.000000  30139.000000
# mean      38.441720  1.897950e+05      10.122532   1092.841202     88.439928
# std       13.131426  1.056586e+05       2.548738   7409.110596    404.445239
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.176275e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.784170e+05      10.000000      0.000000      0.000000
# 75%       47.000000  2.376045e+05      13.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    30139.000000
# mean        40.934703
# std         11.978753
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Age frequency distribution

# %%
data['age'].plot(kind='hist', bins=20, colormap='Pastel1', fontsize=14)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Work Class frequency distribution

# %%
#f, ax = plt.subplots(figsize=(14, 8))
data['work-class'].hist(xrot=30, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=7, rwidth=0.9)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Final Weight frequency distribution

# %%
data['fnlwgt'].plot(kind='hist', bins=20, colormap='Pastel1', fontsize=14)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Marital Status frequency distribution

# %%
#f, ax = plt.subplots(figsize=(14, 8))
data['marital-status'].hist(xrot=45, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=7, rwidth=0.9)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Occupation frequency distribution

# %%
#f, ax = plt.subplots(figsize=(14, 8))
data['occupation'].hist(xrot=60, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=14, rwidth=0.9)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Relationship frequency distribution

# %%
#f, ax = plt.subplots(figsize=(14, 8))
data['relationship'].hist(xrot=20, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=6, rwidth=0.9)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Sex frequency distribution

# %%
#f, ax = plt.subplots(figsize=(14, 8))
data['sex'].hist(xrot=10, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=2, rwidth=0.9)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Capital Gain frequency distribution

# %%
data['capital-gain'].plot(kind='hist', bins=20, colormap='Pastel1', fontsize=14, log=True)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Capital Loss frequency distribution

# %%
data['capital-loss'].plot(kind='hist', bins=20, colormap='Pastel1', fontsize=14, log=True)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Native Country frequency distribution

# %%
f, ax = plt.subplots(figsize=(14, 6))
data['native-country'].hist(xrot=90, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=41, rwidth=0.9, log=True)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Income frequency distribution

# %%
# f, ax = plt.subplots(figsize=(14, 6))
data['income'].hist(xrot=0, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12, bins=2, rwidth=0.9)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Hours-per-week frequency distribution

# %%
data['hours-per-week'].plot(kind='hist', bins=20, colormap='Pastel1', fontsize=14)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Education frequency distribution

# %%
data['education-num'].plot(kind='hist', bins=16, colormap='Pastel1', fontsize=14)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### US native / Other countries ratio

# %%
count_us = sum(data['native-country'] == 'United-States')

plt.pie([
    count_us,
    data.shape[0] - count_us
],
autopct='%.0f%%', textprops={'size': '18'},
colors=plt.colormaps["Pastel1"]([0, 1]))
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ece90d776d0>,
#   <matplotlib.patches.Wedge at 0x7ece90d77610>],
#  [Text(-1.0582376915662706, 0.30022156509566617, ''),
#   Text(1.058237684539077, -0.30022158986550723, '')],
#  [Text(-0.5772205590361474, 0.1637572173249088, '91%'),
#   Text(0.5772205552031329, -0.16375723083573118, '9%')])

# %% [markdown]
# ### How many native to Thailand in the dataset

# %%
sum(data['native-country'] == 'Thailand')
# Out:
# 17

# %%
sum(data['native-country'] == 'Thailand') / data.shape[0] * 100
# Out:
# 0.05640532200802946

# %%
nc_mean_eds = []
for nc in data['native-country'].unique():
    mean_ed = data.loc[data['native-country'] == nc]['education-num'].mean()
    nc_mean_eds.append((nc, mean_ed))
print('Top 3 Native Countries with Highest Education :')
for nc, mean_ed in sorted(nc_mean_eds, key=lambda x: x[1], reverse=True)[:3]:
    print(nc, mean_ed)
print()
print('Top 3 Native Countries with Lowest Education :')
for nc, mean_ed in sorted(nc_mean_eds, key=lambda x: x[1], reverse=False)[:3]:
    print(nc, mean_ed)
# Out:
# Top 3 Native Countries with Highest Education :
# Taiwan 13.476190476190476
# Iran 12.452380952380953
# India 12.43
#
# Top 3 Native Countries with Lowest Education :
# Mexico 6.145214521452146
# Guatemala 6.19672131147541
# Portugal 6.852941176470588

# %%
for nc in ['Taiwan', 'Iran', 'India']:
    quantile = data.loc[data['native-country'] == nc]['education-num'].quantile(.25)
    print(nc, quantile)
print()
for nc in ['Mexico', 'Guatemala', 'Portugal']:
    quantile = data.loc[data['native-country'] == nc]['education-num'].quantile(.75)
    print(nc, quantile)
# Out:
# Taiwan 13.0
# Iran 10.0
# India 10.0
#
# Mexico 9.0
# Guatemala 9.0
# Portugal 9.0

# %% [markdown]
# ### <=50K/>50K income ratio

# %%
plt.pie([
    sum(data['income'] == '<=50K'),
    sum(data['income'] == '>50K')
],
autopct='%.0f%%', textprops={'size': '18'},
colors=plt.colormaps["Pastel1"]([0, 1]))
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ece90dda9b0>,
#   <matplotlib.patches.Wedge at 0x7ece90dda8f0>],
#  [Text(-0.7801449305292097, 0.7754830026309891, ''),
#   Text(0.7801449305292096, -0.7754830026309892, '')],
#  [Text(-0.425533598470478, 0.4229907287078122, '75%'),
#   Text(0.42553359847047795, -0.42299072870781224, '25%')])

# %% [markdown]
# ### Race frequency distribution

# %%
data['race'].hist(xrot=20, color=plt.colormaps["Pastel1"]([0]), xlabelsize=12, ylabelsize=12)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
# Out:
# <Axes: >

# %% [markdown]
# ### Income-sex crosstab heatmap

# %%
income_sex_cross = pd.crosstab(data['income'], data['sex'], normalize='index')

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 6))

# plt.rcParams.update({'font.size': 25})

# Draw the heatmap
_ = sns.heatmap(income_sex_cross*100, cmap="OrRd", square=True, ax=ax, annot=True, linewidth=5)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Occupation-Education crosstab heatmap

# %%
oc_ed_cross = pd.crosstab(data['occupation'], data['education-num'], normalize='index')

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(14, 8))

# plt.rcParams.update({'font.size': 10})

# Draw the heatmap
_ = sns.heatmap(oc_ed_cross*100, cmap="OrRd", square=True, ax=ax, annot=True, linewidth=0.1)
# plt.savefig('fig.png', transparent=True, bbox_inches='tight')
