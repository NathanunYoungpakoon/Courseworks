# %% [markdown]
# # Week 9 - Gradient Descent

# %% [markdown]
# ## Assignment

# %% [markdown]
# Use Least Square Estimation and Gradient Descent to find the
# slope and intercept for input data in the figure below

# %% [markdown]
# ![week9.png](data:image/png;base64,...)

# %% [markdown]
# According to the fingure above, the observed data points ($x$, $y$) are the following:
#
# | i | x | y  |
# |---|---|----|
# | 1 | 1 | 11 |
# | 2 | 3 | 16 |
# | 3 | 4 | 15 |
# | 4 | 6 | 20 |
# | 5 | 8 | 18 |

# %% [markdown]
# ### Find the slope and intercept with Least Square Estimation

# %% [markdown]
# Let $N$ be the number of observed data points (in this case, $N=5$).
# Using an alternative form of Least Square (easy to calculate by hand),
# then, the slope $m$ and the intercept $b$ are as the following:
#
# \begin{align*}
# &m=\frac{N\sum_{i=1}^{N}x_{i}y_{i}-\left(\sum_{i=1}^{N}x_{i}\right)\left(\sum_{i=1}^{N}y_{i}\right)}{N\left(\sum_{i=1}^{N}x_{i}^{2}\right)-\left(\sum_{i=1}^{N}x_{i}\right)^{2}} \\
# &b=\frac{\left(\sum_{i=1}^{N}y_{i}\right)-m\left(\sum_{i=1}^{N}x_{i}\right)}{N}
# \end{align*}
#
# Solving for each term,
# \begin{align*}
# &\sum_{i=1}^{N}x_{i}=1+3+4+6+8=22 \\
# &\sum_{i=1}^{N}y_{i}=11+16+15+20+18=80 \\
# &\sum_{i=1}^{N}x_{i}y_{i}=\left(1\times11\right)+\left(3\times16\right)+\left(4\times15\right)+\left(6\times20\right)+\left(8\times18\right)=383 \\
# &\sum_{i=1}^{N}x_{i}^{2}=1^{2}+3^{2}+4^{2}+6^{2}+8^{2}=126
# \end{align*}
#
# Finally, solving for the slope $m$ and the intercept $b$.
# \begin{align*}
# &m=\frac{\left(5\times383\right)-\left(22\times80\right)}{\left(5\times126\right)-22^{2}}=1.06164383562 \\
# &b=\frac{80-22m}{5}=11.3287671233
# \end{align*}

# %% [markdown]
# ### Loss function: Sum of square residual

# %% [markdown]
# Given that the equation for Sum of Square Residual (SSE) is:
# $$
# SSE=\sum_{i=1}^{N}\left(y_{i}-\hat{y}_{i}\right)^{2}
# $$
#
# Using the previously solved $m$ and $b$, then:
# \begin{align*}
# \sum_{i=1}^{N}\left(y_{i}-\hat{y}_{i}\right)^{2}&=\left(11-\left(1m+b\right)\right)^{2}+\left(16-\left(3m+b\right)\right)^{2}+\left(15-\left(4m+b\right)\right)^{2}+\left(20-\left(6m+b\right)\right)^{2}+\left(18-\left(8m+b\right)\right)^{2} \\
# &=\left(11-12.39\right)^{2}+\left(16-14.51\right)^{2}+\left(15-15.58\right)^{2}+\left(20-17.70\right)^{2}+\left(18-19.82\right)^{2} \\
# &=13.091
# \end{align*}

# %% [markdown]
# ### Use the Gradient Descent algorithm with a learning rate = 0.01, and the slope from Least Square Estimation (Repeat the 6 steps 10 times)

# %% [markdown]
# Given the loss function of the intercept $b$ as the following:
#
# $$
# L\left(b\right)=\sum_{i=1}^{N}\left(y_{i}-\left(mx_{i}+b\right)\right)^{2}
# $$
#
# where $m$ is the previously solved slope value, then the derivative of $L\left(b\right)$ is:
#
# \begin{align*}
# \frac{dL}{db}=L'\left(b\right)&=-2\sum_{i=1}^{N}\left(y_{i}-\left(mx_{i}+b\right)\right) \\
# &=-2\left(\left(11-\left(1m+b\right)\right)+\left(16-\left(3m+b\right)\right)+\left(15-\left(4m+b\right)\right)+\left(20-\left(6m+b\right)\right)+\left(18-\left(8m+b\right)\right)\right) \\
# &=10b-113.287671233
# \end{align*}
#
# Let the start value for the intercept $b_0$ be $0.1$, and the learning rate ($LR$) be 0.01, then:
# \begin{align*}
# b_{\left(i+1\right)}&=b_{i}-LR\times L'\left(b_{i}\right) \\
# b_{1}&=b_{0}-LR\times L'\left(b_{0}\right) \\
# &=0.1-0.01\times L'\left(0.1\right) \\
# &=1.22287671233
# \end{align*}
#
# Calculate for the additional 9 times:
# \begin{align*}
# b_{2}&=b_{1}-0.01\times L'\left(b_{1}\right) \\
# &=1.22287671233-0.01\times L'\left(1.22287671233\right) \\
# &=2.23346575343 \\
# b_{3}&=b_{2}-0.01\times L'\left(b_{2}\right) \\
# &=2.23346575343-0.01\times L'\left(2.23346575343\right) \\
# &=3.14299589042 \\
# b_{4}&=b_{3}-0.01\times L'\left(b_{3}\right) \\
# &=3.14299589042-0.01\times L'\left(3.14299589042\right) \\
# &=3.96157301371 \\
# b_{5}&=b_{4}-0.01\times L'\left(b_{4}\right) \\
# &=3.96157301371-0.01\times L'\left(3.96157301371\right) \\
# &=4.69829242467 \\
# b_{6}&=b_{5}-0.01\times L'\left(b_{5}\right) \\
# &=4.69829242467-0.01\times L'\left(4.69829242467\right) \\
# &=5.36133989453 \\
# b_{7}&=b_{6}-0.01\times L'\left(b_{6}\right) \\
# &=5.36133989453-0.01\times L'\left(5.36133989453\right) \\
# &=5.95808261741 \\
# b_{8}&=b_{7}-0.01\times L'\left(b_{7}\right) \\
# &=5.95808261741-0.01\times L'\left(5.95808261741\right) \\
# &=6.495151068 \\
# b_{9}&=b_{8}-0.01\times L'\left(b_{8}\right) \\
# &=6.495151068-0.01\times L'\left(6.495151068\right) \\
# &=6.97851267353 \\
# b_{10}&=b_{9}-0.01\times L'\left(b_{9}\right) \\
# &=6.97851267353-0.01\times L'\left(6.97851267353\right) \\
# &=7.41353811851 \\
# \end{align*}

# %% [markdown]
# ### Plot a line based on the calculated slope and intercept

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([1, 3, 4, 6, 8])
Y = np.array([11, 16, 15, 20, 18])

Y_pred = 1.06164383562*X + 7.41353811851
plt.figure(figsize = (8,6))
plt.scatter(X, Y, marker='o', color='red')
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='blue',markerfacecolor='red',
          markersize=10,linestyle='dashed')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## Python Code for Gradient Descent

# %% [markdown]
# https://www.geeksforgeeks.org/how-to-implement-a-gradient-descent-in-python-to-find-a-local-minimum/

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_squared_error(y_true, y_predicted):

    # Calculating the loss or cost
    cost = np.sum((y_true-y_predicted)**2) / len(y_true)
    return cost

# Gradient Descent Function
# Here iterations, learning_rate, stopping_threshold
# are hyperparameters that can be tuned
def gradient_descent(x, y, iterations = 1000, learning_rate = 0.0001,
                     stopping_threshold = 1e-6):

    # Initializing weight, bias, learning rate and iterations
    current_weight = 0.1
    current_bias = 0.01
    iterations = iterations
    learning_rate = learning_rate
    n = float(len(x))

    costs = []
    weights = []
    previous_cost = None

    # Estimation of optimal parameters
    for i in range(iterations):

        # Making predictions
        y_predicted = (current_weight * x) + current_bias

        # Calculationg the current cost
        current_cost = mean_squared_error(y, y_predicted)

        # If the change in cost is less than or equal to
        # stopping_threshold we stop the gradient descent
        if previous_cost and abs(previous_cost-current_cost)<=stopping_threshold:
            break

        previous_cost = current_cost

        costs.append(current_cost)
        weights.append(current_weight)

        # Calculating the gradients
        weight_derivative = -(2/n) * sum(x * (y-y_predicted))
        bias_derivative = -(2/n) * sum(y-y_predicted)

        # Updating weights and bias
        current_weight = current_weight - (learning_rate * weight_derivative)
        current_bias = current_bias - (learning_rate * bias_derivative)

        # Printing the parameters for each 1000th iteration
        print(f"Iteration {i+1}: Cost {current_cost}, Weight {current_weight}, Bias {current_bias}")


    # Visualizing the weights and cost at for all iterations
    plt.figure(figsize = (8,6))
    plt.plot(weights, costs)
    plt.scatter(weights, costs, marker='o', color='red')
    plt.title("Cost vs Weights")
    plt.ylabel("Cost")
    plt.xlabel("Weight")
    plt.show()

    return current_weight, current_bias


def main():

    # Data
    X = np.array([1, 3, 4, 6, 8])
    Y = np.array([11, 16, 15, 20, 18])

    # Estimating weight and bias using gradient descent
    estimated_weight, eatimated_bias = gradient_descent(X, Y, 10, 0.01)
    print(f"Estimated Weight: {estimated_weight}\nEstimated Bias: {eatimated_bias}")

    # Making predictions using estimated parameters
    Y_pred = estimated_weight*X + eatimated_bias

    # Plotting the regression line
    plt.figure(figsize = (8,6))
    plt.scatter(X, Y, marker='o', color='red')
    plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='blue',markerfacecolor='red',
             markersize=10,linestyle='dashed')
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.show()


if __name__=="__main__":
    main()
# Out:
# Iteration 1: Cost 249.82090000000002, Weight 1.5807200000000001, Bias 0.321
# Iteration 2: Cost 80.29658295968001, Weight 2.2877891200000002, Bias 0.49547664
# Iteration 3: Cost 40.9724290706773, Weight 2.6231414592, Bias 0.60424166464
# Iteration 4: Cost 31.710155253369543, Weight 2.77990489727488, Bias 0.6813203829376
# Iteration 5: Cost 29.39012179103612, Weight 2.850876635349832, Bias 0.7430623443186586
# Iteration 6: Cost 28.67452123037095, Weight 2.8806453248334747, Bias 0.7973239535215002
# Iteration 7: Cost 28.330962062290872, Weight 2.8906355732075117, Bias 0.8478806858657244
# Iteration 8: Cost 28.0748989622183, Weight 2.891141743954742, Bias 0.8965471417061489
# Iteration 9: Cost 27.840622604435026, Weight 2.8871101565314112, Bias 0.9441957254040086
# Iteration 10: Cost 27.612947987584455, Weight 2.880917413804027, Bias 0.9912461171211643
# Estimated Weight: 2.880917413804027
# Estimated Bias: 0.9912461171211643
