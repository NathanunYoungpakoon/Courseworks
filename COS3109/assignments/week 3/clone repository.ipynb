# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Clone the Repository

# %%
# %%bash
#
# cd /gdrive/MyDrive/Assignments/COS3109/Week3
# git clone https://github.com/Laksheeta/Simple-Reflex-Vaccum-Agent
# Out:
# Cloning into 'Simple-Reflex-Vaccum-Agent'...
