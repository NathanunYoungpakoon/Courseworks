# %%
import random


class Environment(object):
    def __init__(self):
        self.locationCondition = {'A': '0', 'B': '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print (Environment.locationCondition)
        Score = 0
        vacuumLocation = random.randint(0, 1)
        if vacuumLocation == 0:
            print ("Vacuum is randomly placed at Location A.")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print("Environment is Clean.")

        elif vacuumLocation == 1:
            print ("Vacuum randomly placed at Location B.")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print("Environment is Clean.")

        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment()
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 1, 'B': 1}
# Vacuum randomly placed at Location B.
# Location B is Dirty.
# Location B has been Cleaned.
# Moving to Location A...
# Location A is Dirty.
# Location A has been Cleaned.
# Environment is Clean.
# {'A': 0, 'B': 0}
# Performance Measurement: 2

# %% [markdown]
# ![image](https://lh3.googleusercontent.com/drive-viewer/AEYmBYRn58sZqkiTF26VU4Zuq4op-R5udx-TlgRuqDK0CJhhk_1VaGT-ENkNXkZ0maXBlgYcJUGwJPeCsXwiAoemTaFUZaL6pg=w1920-h972)

# %% [markdown]
# | Perception Sequence      | Action |
# | ----------- | ----------- |
# | Environment.locationCondition['A'] == 0      | "Moving to Location B..."       |
# | Environment.locationCondition['B'] == 0   | "Moving to Location A..."        |
# | Environment.locationCondition['A'] == 1   | Environment.locationCondition['A'] = 0        |
# | Environment.locationCondition['B'] == 1   | Environment.locationCondition['B'] = 0        |

# %% [markdown]
# ![image](https://lh3.googleusercontent.com/drive-viewer/AEYmBYRhTEKF5U4RcEQb7oJt29_Lh8rR0zQYWOzhxmla9hrBmWDA7803umffjGclCNokaAqZ8kiyz9jzZAYiUm5tFo8UOuQN=w1920-h972)

# %% [markdown]
# # Vacuum Cleaner
# **Agent Name**: SimpleReflexVacuumAgent
# **Performance measure**: `SimpleReflexVacuumAgent.Score`
# **Environment**: `Environment.locationCondition`
# **Actuators**:
# - `Environment.locationCondition['A'] = 0`
# - `Environment.locationCondition['B'] = 0`
#
# **Sensors**:
# - `if Environment.locationCondition['A'] == 1`
# - `if Environment.locationCondition['B'] == 1`
#
# ## Environment Terminology
#
# - Fully Observable
#   - All information in the environment can be accessed via object `Environment.locationCondition`.
# - Single
#   - Only one instance/agent is created (`theVacuum`) for an environment.
# - Stochastic
#   - The environment's conditions (`Environment.locationCondition`) and the vacuum's location (`SimpleReflexVacuumAgent.vacuumLocation`) have been initialized randomly with `random.randint(0, 1)`.
# - Static
#   - After the random initialization, the environment does not change on its own throughout the agent life time.
# - Discrete
#   - Actuators and Sensors have distinct actions
# - Benign
#   - Because the environment does not change, the agent is free to maximize its performance without any hindering
# - Episodic
#   - The agent's actions only change the current location that it's in, which does not affect its future action for other location
